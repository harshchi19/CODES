# %% [markdown]
# Breast Cancer - Naive Bayes

# %%
pip install pgmpy

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.metrics import accuracy_score
from sklearn.impute import SimpleImputer
from sklearn.naive_bayes import GaussianNB
from pgmpy.models import BayesianNetwork
from pgmpy.estimators import MaximumLikelihoodEstimator
from pgmpy.inference import VariableElimination
import networkx as nx

file_path = "icancer_data.csv"  
target_col = "diagnosis"  # Replace 'target' (CHANGE 1)

df = pd.read_csv(file_path)
label_encoders = {}
for col in df.select_dtypes(include='object').columns:
    le = LabelEncoder()
    df[col] = le.fit_transform(df[col])
    label_encoders[col] = le

X = df.drop(columns=[target_col])
y = df[target_col]

impute = SimpleImputer(strategy="mean")
X = impute.fit_transform(X)

sc = StandardScaler()
X_scaled = sc.fit_transform(X)

X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=22)

bayes = GaussianNB()
bayes.fit(X_train, y_train)

y_pred = bayes.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
print(f"Naive Bayes Accuracy: {accuracy:.4f}")


# Bayesian Network
features = ['radius_mean', 'texture_mean'] #CHANGE 2
structure = [(feature, target_col) for feature in features]
naive_bayes = BayesianNetwork(structure)

naive_bayes.fit(df, estimator=MaximumLikelihoodEstimator)

# CPDs
print("\nConditional Probability Distributions (CPDs):")
for cpd in naive_bayes.get_cpds():
    print(f"CPD of {cpd.variable}:")
    print(cpd)

# Inference
infer = VariableElimination(naive_bayes)
query_result = infer.query(variables=['diagnosis'], evidence={'radius_mean': 17.99}) #CHANGE 3
print("\nQuery Result:")
print(query_result)

# Visualization
def plot_dag(model):
    pos = nx.spring_layout(model)
    nx.draw(model, pos, with_labels=True, node_size=2000, node_color='lightblue', font_size=10, font_weight='bold')
    plt.title("Bayesian Network DAG", fontsize=14)
    plt.show()

dag = nx.DiGraph(naive_bayes.edges())
plot_dag(dag)
# Out:
# C:\Users\KEYUR JAIN\AppData\Roaming\Python\Python311\site-packages\sklearn\impute\_base.py:598: UserWarning: Skipping features without any observed values: ['Unnamed: 32']. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# Naive Bayes Accuracy: 0.9649
#
# Conditional Probability Distributions (CPDs):
# CPD of radius_mean:
# +--------------------+------------+
# | radius_mean(6.981) | 0.00175747 |
# +--------------------+------------+
# | radius_mean(7.691) | 0.00175747 |
# +--------------------+------------+
# | radius_mean(7.729) | 0.00175747 |
# +--------------------+------------+
# | radius_mean(7.76)  | 0.00175747 |
# +--------------------+------------+
# | radius_mean(8.196) | 0.00175747 |
# +--------------------+------------+
# | radius_mean(8.219) | 0.00175747 |
# +--------------------+------------+
# | radius_mean(8.571) | 0.00175747 |
# +--------------------+------------+
# | radius_mean(8.597) | 0.00175747 |
# +--------------------+------------+
# | radius_mean(8.598) | 0.00175747 |
# +--------------------+------------+
# | radius_mean(8.618) | 0.00175747 |
# +--------------------+------------+
# | radius_mean(8.671) | 0.00175747 |
# +--------------------+------------+
# | radius_mean(8.726) | 0.00175747 |
# +--------------------+------------+
# | radius_mean(8.734) | 0.00175747 |
# +--------------------+------------+
# | radius_mean(8.878) | 0.00175747 |
# +--------------------+------------+
# | radius_mean(8.888) | 0.00175747 |
# +--------------------+------------+
# | radius_mean(8.95)  | 0.00175747 |
# +--------------------+------------+
# | radius_mean(9.0)   | 0.00175747 |
# +--------------------+------------+
# | radius_mean(9.029) | 0.00175747 |
# +--------------------+------------+
# | radius_mean(9.042) | 0.00175747 |
# +--------------------+------------+
# | radius_mean(9.173) | 0.00175747 |
# +--------------------+------------+
# | radius_mean(9.268) | 0.00175747 |
# +--------------------+------------+
# | radius_mean(9.295) | 0.00175747 |
# +--------------------+------------+
# | radius_mean(9.333) | 0.00175747 |
# +--------------------+------------+
# | radius_mean(9.397) | 0.00175747 |
# +--------------------+------------+
# | radius_mean(9.405) | 0.00175747 |
# +--------------------+------------+
# | radius_mean(9.423) | 0.00175747 |
# +--------------------+------------+
# | radius_mean(9.436) | 0.00175747 |
# +--------------------+------------+
# | radius_mean(9.465) | 0.00175747 |
# +--------------------+------------+
# | radius_mean(9.504) | 0.00175747 |
# +--------------------+------------+
# | radius_mean(9.567) | 0.00175747 |
# +--------------------+------------+
# | radius_mean(9.606) | 0.00175747 |
# +--------------------+------------+
# | radius_mean(9.667) | 0.00175747 |
# +--------------------+------------+
# | radius_mean(9.668) | 0.00175747 |
# +--------------------+------------+
# | radius_mean(9.676) | 0.00175747 |
# +--------------------+------------+
# | radius_mean(9.683) | 0.00175747 |
# +--------------------+------------+
# | radius_mean(9.72)  | 0.00175747 |
# +--------------------+------------+
# | radius_mean(9.731) | 0.00175747 |
# +--------------------+------------+
# | radius_mean(9.738) | 0.00175747 |
# +--------------------+------------+
# | radius_mean(9.742) | 0.00351494 |
# +--------------------+------------+
# | radius_mean(9.755) | 0.00175747 |
# +--------------------+------------+
# | radius_mean(9.777) | 0.00175747 |
# +--------------------+------------+
# | radius_mean(9.787) | 0.00175747 |
# +--------------------+------------+
# | radius_mean(9.847) | 0.00175747 |
# +--------------------+------------+
# | radius_mean(9.876) | 0.00351494 |
# +--------------------+------------+
# | radius_mean(9.904) | 0.00175747 |
# +--------------------+------------+
# | radius_mean(10.03) | 0.00175747 |
# +--------------------+------------+
# | radius_mean(10.05) | 0.00175747 |
# +--------------------+------------+
# | radius_mean(10.08) | 0.00175747 |
# +--------------------+------------+
# | radius_mean(10.16) | 0.00175747 |
# +--------------------+------------+
# | radius_mean(10.17) | 0.00175747 |
# +--------------------+------------+
# | radius_mean(10.18) | 0.00175747 |
# +--------------------+------------+
# | radius_mean(10.2)  | 0.00175747 |
# +--------------------+------------+
# | radius_mean(10.25) | 0.00175747 |
# +--------------------+------------+
# | radius_mean(10.26) | 0.00527241 |
# +--------------------+------------+
# | radius_mean(10.29) | 0.00175747 |
# +--------------------+------------+
# | radius_mean(10.32) | 0.00175747 |
# +--------------------+------------+
# | radius_mean(10.44) | 0.00175747 |
# +--------------------+------------+
# | radius_mean(10.48) | 0.00351494 |
# +--------------------+------------+
# | radius_mean(10.49) | 0.00351494 |
# +--------------------+------------+
# | radius_mean(10.51) | 0.00351494 |
# +--------------------+------------+
# | radius_mean(10.57) | 0.00351494 |
# +--------------------+------------+
# | radius_mean(10.6)  | 0.00175747 |
# +--------------------+------------+
# | radius_mean(10.65) | 0.00175747 |
# +--------------------+------------+
# | radius_mean(10.66) | 0.00175747 |
# +--------------------+------------+
# | radius_mean(10.71) | 0.00175747 |
# +--------------------+------------+
# | radius_mean(10.75) | 0.00175747 |
# +--------------------+------------+
# | radius_mean(10.8)  | 0.00351494 |
# +--------------------+------------+
# | radius_mean(10.82) | 0.00175747 |
# +--------------------+------------+
# | radius_mean(10.86) | 0.00175747 |
# +--------------------+------------+
# | radius_mean(10.88) | 0.00175747 |
# +--------------------+------------+
# | radius_mean(10.9)  | 0.00175747 |
# +--------------------+------------+
# | radius_mean(10.91) | 0.00175747 |
# +--------------------+------------+
# | radius_mean(10.94) | 0.00175747 |
# +--------------------+------------+
# | radius_mean(10.95) | 0.00175747 |
# +--------------------+------------+
# | radius_mean(10.96) | 0.00175747 |
# +--------------------+------------+
# | radius_mean(10.97) | 0.00175747 |
# +--------------------+------------+
# | radius_mean(11.04) | 0.00351494 |
# +--------------------+------------+
# | radius_mean(11.06) | 0.00527241 |
# +--------------------+------------+
# | radius_mean(11.08) | 0.00351494 |
# +--------------------+------------+
# | radius_mean(11.13) | 0.00351494 |
# +--------------------+------------+
# | radius_mean(11.14) | 0.00175747 |
# +--------------------+------------+
# | radius_mean(11.15) | 0.00175747 |
# +--------------------+------------+
# | radius_mean(11.16) | 0.00175747 |
# +--------------------+------------+
# | radius_mean(11.2)  | 0.00175747 |
# +--------------------+------------+
# | radius_mean(11.22) | 0.00351494 |
# +--------------------+------------+
# | radius_mean(11.25) | 0.00175747 |
# +--------------------+------------+
# | radius_mean(11.26) | 0.00351494 |
# +--------------------+------------+
# | radius_mean(11.27) | 0.00351494 |
# +--------------------+------------+
# | radius_mean(11.28) | 0.00175747 |
# +--------------------+------------+
# | radius_mean(11.29) | 0.00175747 |
# +--------------------+------------+
# | radius_mean(11.3)  | 0.00175747 |
# +--------------------+------------+
# | radius_mean(11.31) | 0.00175747 |
# +--------------------+------------+
# | radius_mean(11.32) | 0.00175747 |
# +--------------------+------------+
# | radius_mean(11.33) | 0.00175747 |
# +--------------------+------------+
# | radius_mean(11.34) | 0.00351494 |
# +--------------------+------------+
# | radius_mean(11.36) | 0.00175747 |
# +--------------------+------------+
# | radius_mean(11.37) | 0.00175747 |
# +--------------------+------------+
# | radius_mean(11.41) | 0.00351494 |
# +--------------------+------------+
# | radius_mean(11.42) | 0.00175747 |
# +--------------------+------------+
# | radius_mean(11.43) | 0.00351494 |
# +--------------------+------------+
# | radius_mean(11.45) | 0.00175747 |
# +--------------------+------------+
# | radius_mean(11.46) | 0.00175747 |
# +--------------------+------------+
# | radius_mean(11.47) | 0.00175747 |
# +--------------------+------------+
# | radius_mean(11.49) | 0.00175747 |
# +--------------------+------------+
# | radius_mean(11.5)  | 0.00175747 |
# +--------------------+------------+
# | radius_mean(11.51) | 0.00175747 |
# +--------------------+------------+
# | radius_mean(11.52) | 0.00351494 |
# +--------------------+------------+
# | radius_mean(11.54) | 0.00351494 |
# +--------------------+------------+
# | radius_mean(11.57) | 0.00175747 |
# +--------------------+------------+
# | radius_mean(11.6)  | 0.00527241 |
# +--------------------+------------+
# | radius_mean(11.61) | 0.00175747 |
# +--------------------+------------+
# | radius_mean(11.62) | 0.00175747 |
# +--------------------+------------+
# | radius_mean(11.63) | 0.00175747 |
# +--------------------+------------+
# | radius_mean(11.64) | 0.00175747 |
# +--------------------+------------+
# | radius_mean(11.66) | 0.00175747 |
# +--------------------+------------+
# | radius_mean(11.67) | 0.00175747 |
# +--------------------+------------+
# | radius_mean(11
| 0.00175747 |
# +--------------------+------------+
# | radius_mean(20.16) | 0.00175747 |
# +--------------------+------------+
# | radius_mean(20.18) | 0.00351494 |
# +--------------------+------------+
# | radius_mean(20.2)  | 0.00175747 |
# +--------------------+------------+
# | radius_mean(20.26) | 0.00175747 |
# +--------------------+------------+
# | radius_mean(20.29) | 0.00175747 |
# +--------------------+------------+
# | radius_mean(20.31) | 0.00175747 |
# +--------------------+------------+
# | radius_mean(20.34) | 0.00175747 |
# +--------------------+------------+
# | radius_mean(20.44) | 0.00175747 |
# +--------------------+------------+
# | radius_mean(20.47) | 0.00175747 |
# +--------------------+------------+
# | radius_mean(20.48) | 0.00175747 |
# +--------------------+------------+
# | radius_mean(20.51) | 0.00175747 |
# +--------------------+------------+
# | radius_mean(20.55) | 0.00175747 |
# +--------------------+------------+
# | radius_mean(20.57) | 0.00175747 |
# +--------------------+------------+
# | radius_mean(20.58) | 0.00175747 |
# +--------------------+------------+
# | radius_mean(20.59) | 0.00175747 |
# +--------------------+------------+
# | radius_mean(20.6)  | 0.00175747 |
# +--------------------+------------+
# | radius_mean(20.64) | 0.00175747 |
# +--------------------+------------+
# | radius_mean(20.73) | 0.00175747 |
# +--------------------+------------+
# | radius_mean(20.92) | 0.00175747 |
# +--------------------+------------+
# | radius_mean(20.94) | 0.00175747 |
# +--------------------+------------+
# | radius_mean(21.09) | 0.00175747 |
# +--------------------+------------+
# | radius_mean(21.1)  | 0.00175747 |
# +--------------------+------------+
# | radius_mean(21.16) | 0.00175747 |
# +--------------------+------------+
# | radius_mean(21.37) | 0.00175747 |
# +--------------------+------------+
# | radius_mean(21.56) | 0.00175747 |
# +--------------------+------------+
# | radius_mean(21.61) | 0.00175747 |
# +--------------------+------------+
# | radius_mean(21.71) | 0.00175747 |
# +--------------------+------------+
# | radius_mean(21.75) | 0.00175747 |
# +--------------------+------------+
# | radius_mean(22.01) | 0.00175747 |
# +--------------------+------------+
# | radius_mean(22.27) | 0.00175747 |
# +--------------------+------------+
# | radius_mean(23.09) | 0.00175747 |
# +--------------------+------------+
# | radius_mean(23.21) | 0.00175747 |
# +--------------------+------------+
# | radius_mean(23.27) | 0.00175747 |
# +--------------------+------------+
# | radius_mean(23.29) | 0.00175747 |
# +--------------------+------------+
# | radius_mean(23.51) | 0.00175747 |
# +--------------------+------------+
# | radius_mean(24.25) | 0.00175747 |
# +--------------------+------------+
# | radius_mean(24.63) | 0.00175747 |
# +--------------------+------------+
# | radius_mean(25.22) | 0.00175747 |
# +--------------------+------------+
# | radius_mean(25.73) | 0.00175747 |
# +--------------------+------------+
# | radius_mean(27.22) | 0.00175747 |
# +--------------------+------------+
# | radius_mean(27.42) | 0.00175747 |
# +--------------------+------------+
# | radius_mean(28.11) | 0.00175747 |
# +--------------------+------------+
# CPD of diagnosis:
# +--------------+--------------------+-----+---------------------+
# | radius_mean  | radius_mean(6.981) | ... | radius_mean(28.11)  |
# +--------------+--------------------+-----+---------------------+
# | texture_mean | texture_mean(9.71) | ... | texture_mean(39.28) |
# +--------------+--------------------+-----+---------------------+
# | diagnosis(0) | 0.5                | ... | 0.5                 |
# +--------------+--------------------+-----+---------------------+
# | diagnosis(1) | 0.5                | ... | 0.5                 |
# +--------------+--------------------+-----+---------------------+
# CPD of texture_mean:
# +---------------------+------------+
# | texture_mean(9.71)  | 0.00175747 |
# +---------------------+------------+
# | texture_mean(10.38) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(10.72) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(10.82) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(10.89) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(10.91) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(10.94) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(11.28) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(11.79) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(11.89) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(11.97) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(12.17) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(12.22) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(12.27) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(12.35) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(12.39) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(12.44) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(12.71) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(12.74) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(12.83) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(12.84) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(12.87) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(12.88) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(12.91) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(12.96) | 0.00351494 |
# +---------------------+------------+
# | texture_mean(13.04) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(13.06) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(13.08) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(13.1)  | 0.00175747 |
# +---------------------+------------+
# | texture_mean(13.12) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(13.14) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(13.16) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(13.17) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(13.21) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(13.23) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(13.27) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(13.29) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(13.32) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(13.37) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(13.39) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(13.43) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(13.44) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(13.47) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(13.66) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(13.72) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(13.78) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(13.84) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(13.86) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(13.9)  | 0.00351494 |
# +---------------------+------------+
# | texture_mean(13.93) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(13.98) | 0.00351494 |
# +---------------------+------------+
# | texture_mean(14.02) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(14.06) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(14.07) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(14.08) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(14.09) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(14.11) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(14.16) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(14.23) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(14.26) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(14.34) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(14.36) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(14.4)  | 0.00175747 |
# +---------------------+------------+
# | texture_mean(14.44) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(14.45) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(14.59) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(14.63) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(14.64) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(14.65) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(14.69) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(14.7)  | 0.00175747 |
# +---------------------+------------+
# | texture_mean(14.71) | 0.00351494 |
# +---------------------+------------+
# | texture_mean(14.74) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(14.76) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(14.78) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(14.83) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(14.86) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(14.88) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(14.92) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(14.93) | 0.00527241 |
# +---------------------+------------+
# | texture_mean(14.95) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(14.96) | 0.00351494 |
# +---------------------+------------+
# | texture_mean(14.97) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(14.98) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(15.04) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(15.05) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(15.1)  | 0.00175747 |
# +---------------------+------------+
# | texture_mean(15.11) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(15.15) | 0.00351494 |
# +---------------------+------------+
# | texture_mean(15.18) | 0.00351494 |
# +---------------------+------------+
# | texture_mean(15.21) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(15.24) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(15.34) | 0.00351494 |
# +---------------------+------------+
# | texture_mean(15.39) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(15.45) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(15.46) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(15.49) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(15.5)  | 0.00175747 |
# +---------------------+------------+
# | texture_mean(15.51) | 0.00351494 |
# +---------------------+------------+
# | texture_mean(15.56) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(15.6)  | 0.00175747 |
# +---------------------+------------+
# | texture_mean(15.62) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(15.65) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(15.66) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(15.67) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(15.68) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(15.69) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(15.7)  | 0.00527241 |
# +---------------------+------------+
# | texture_mean(15.71) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(15.73) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(15.76) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(15.79) | 0.00351494 |
# +---------------------+------------+
# | texture_mean(15.82) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(15.83) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(15.86) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(15.9)  | 0.00175747 |
# +---------------------+------------+
# | texture_mean(15.91) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(15.92) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(15.94) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(15.98) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(16.02) | 0.00351494 |
# +---------------------+------------+
# | texture_mean(16.03) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(16.07) | 0.00351494 |
# +---------------------+------------+
# | texture_mean(16.15) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(16.16) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(16.17) | 0.00351494 |
# +---------------------+------------+
# | texture_mean(16.18) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(16.21) | 0.00351494 |
# +---------------------+------------+
# | texture_mean(16.32) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(16.33) | 0.00351494 |
# +---------------------+------------+
# | texture_mean(16.34) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(16.35) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(16.39) | 0.00351494 |
# +---------------------+------------+
# | texture_mean(16.4)  | 0.00175747 |
# +---------------------+------------+
# | texture_mean(16.41) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(16.49) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(16.52) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(16.54) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(16.58) | 0.00351494 |
# +---------------------+------------+
# | texture_mean(16.62) | 0.00351494 |
# +---------------------+------------+
# | texture_mean(16.67) | 0.00351494 |
# +---------------------+------------+
# | texture_mean(16.68) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(16.7)  | 0.00175747 |
# +---------------------+------------+
# | texture_mean(16.74) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(16.82) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(16.83) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(16.84) | 0.00527241 |
# +---------------------+------------+
# | texture_mean(16.85) | 0.00527241 |
# +---------------------+------------+
# | texture_mean(16.93) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(16.94) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(16.95) | 0.00351494 |
# +---------------------+------------+
# | texture_mean(16.99) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(17.0)  | 0.00175747 |
# +---------------------+------------+
# | texture_mean(17.02) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(17.05) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(17.07) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(17.08) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(17.12) | 0.00351494 |
# +---------------------+------------+
# | texture_mean(17.15) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(17.18) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(17.19) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(17.2)  | 0.00175747 |
# +---------------------+------------+
# | texture_mean(17.21) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(17.25) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(17.26) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(17.27) | 0.00351494 |
# +---------------------+------------+
# | texture_mean(17.3)  | 0.00175747 |
# +---------------------+------------+
# | texture_mean(17.31) | 0.00351494 |
# +---------------------+------------+
# | texture_mean(17.33) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(17.35) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(17.36) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(17.39) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(17.43) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(17.46) | 0.00527241 |
# +---------------------+------------+
# | texture_mean(17.48) | 0.00351494 |
# +---------------------+------------+
# | texture_mean(17.52) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(17.53) | 0.00351494 |
# +---------------------+------------+
# | texture_mean(17.56) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(17.57) | 0.00351494 |
# +---------------------+------------+
# | texture_mean(17.6)  | 0.00175747 |
# +---------------------+------------+
# | texture_mean(17.62) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(17.64) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(17.66) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(17.67) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(17.68) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(17.72) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(17.77) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(17.84) | 0.00351494 |
# +---------------------+------------+
# | texture_mean(17.88) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(17.89) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(17.91) | 0.00175747 |
# ...
# +---------------------+------------+
# | texture_mean(19.62) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(19.63) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(19.65) | 0.00351494 |
# +---------------------+------------+
# | texture_mean(19.66) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(19.67) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(19.73) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(19.76) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(19.77) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(19.82) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(19.83) | 0.00527241 |
# +---------------------+------------+
# | texture_mean(19.86) | 0.00351494 |
# +---------------------+------------+
# | texture_mean(19.89) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(19.94) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(19.96) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(19.97) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(19.98) | 0.00351494 |
# +---------------------+------------+
# | texture_mean(20.01) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(20.02) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(20.04) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(20.11) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(20.13) | 0.00351494 |
# +---------------------+------------+
# | texture_mean(20.18) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(20.19) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(20.2)  | 0.00351494 |
# +---------------------+------------+
# | texture_mean(20.21) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(20.22) | 0.00351494 |
# +---------------------+------------+
# | texture_mean(20.25) | 0.00351494 |
# +---------------------+------------+
# | texture_mean(20.26) | 0.00351494 |
# +---------------------+------------+
# | texture_mean(20.28) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(20.31) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(20.38) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(20.39) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(20.52) | 0.00527241 |
# +---------------------+------------+
# | texture_mean(20.53) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(20.54) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(20.56) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(20.58) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(20.66) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(20.67) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(20.68) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(20.7)  | 0.00351494 |
# +---------------------+------------+
# | texture_mean(20.71) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(20.74) | 0.00351494 |
# +---------------------+------------+
# | texture_mean(20.76) | 0.00351494 |
# +---------------------+------------+
# | texture_mean(20.78) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(20.82) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(20.83) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(20.86) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(20.97) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(20.98) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(20.99) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(21.0)  | 0.00175747 |
# +---------------------+------------+
# | texture_mean(21.01) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(21.02) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(21.08) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(21.17) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(21.24) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(21.25) | 0.00351494 |
# +---------------------+------------+
# | texture_mean(21.26) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(21.28) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(21.31) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(21.35) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(21.37) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(21.38) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(21.41) | 0.00351494 |
# +---------------------+------------+
# | texture_mean(21.43) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(21.46) | 0.00351494 |
# +---------------------+------------+
# | texture_mean(21.48) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(21.51) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(21.53) | 0.00351494 |
# +---------------------+------------+
# | texture_mean(21.54) | 0.00351494 |
# +---------------------+------------+
# | texture_mean(21.56) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(21.57) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(21.58) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(21.59) | 0.00351494 |
# +---------------------+------------+
# | texture_mean(21.6)  | 0.00351494 |
# +---------------------+------------+
# | texture_mean(21.68) | 0.00351494 |
# +---------------------+------------+
# | texture_mean(21.7)  | 0.00175747 |
# +---------------------+------------+
# | texture_mean(21.72) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(21.78) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(21.8)  | 0.00175747 |
# +---------------------+------------+
# | texture_mean(21.81) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(21.82) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(21.84) | 0.00351494 |
# +---------------------+------------+
# | texture_mean(21.87) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(21.88) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(21.9)  | 0.00175747 |
# +---------------------+------------+
# | texture_mean(21.91) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(21.94) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(21.97) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(21.98) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(22.02) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(22.04) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(22.07) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(22.11) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(22.13) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(22.14) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(22.15) | 0.00351494 |
# +---------------------+------------+
# | texture_mean(22.22) | 0.00351494 |
# +---------------------+------------+
# | texture_mean(22.28) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(22.29) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(22.3)  | 0.00175747 |
# +---------------------+------------+
# | texture_mean(22.33) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(22.39) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(22.41) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(22.44) | 0.00351494 |
# +---------------------+------------+
# | texture_mean(22.47) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(22.49) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(22.53) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(22.54) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(22.55) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(22.61) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(22.68) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(22.72) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(22.76) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(22.91) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(23.03) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(23.04) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(23.06) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(23.09) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(23.12) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(23.2)  | 0.00175747 |
# +---------------------+------------+
# | texture_mean(23.21) | 0.00351494 |
# +---------------------+------------+
# | texture_mean(23.23) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(23.24) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(23.29) | 0.00351494 |
# +---------------------+------------+
# | texture_mean(23.33) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(23.5)  | 0.00175747 |
# +---------------------+------------+
# | texture_mean(23.56) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(23.75) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(23.77) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(23.81) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(23.84) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(23.86) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(23.93) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(23.94) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(23.95) | 0.00351494 |
# +---------------------+------------+
# | texture_mean(23.97) | 0.00351494 |
# +---------------------+------------+
# | texture_mean(23.98) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(24.02) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(24.04) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(24.21) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(24.27) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(24.44) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(24.48) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(24.49) | 0.00351494 |
# +---------------------+------------+
# | texture_mean(24.52) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(24.54) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(24.59) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(24.68) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(24.69) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(24.8)  | 0.00175747 |
# +---------------------+------------+
# | texture_mean(24.81) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(24.89) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(24.91) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(24.98) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(24.99) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(25.0)  | 0.00175747 |
# +---------------------+------------+
# | texture_mean(25.09) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(25.11) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(25.12) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(25.13) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(25.2)  | 0.00175747 |
# +---------------------+------------+
# | texture_mean(25.22) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(25.25) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(25.27) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(25.42) | 0.00351494 |
# +---------------------+------------+
# | texture_mean(25.44) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(25.49) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(25.56) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(25.74) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(26.27) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(26.29) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(26.47) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(26.57) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(26.6)  | 0.00175747 |
# +---------------------+------------+
# | texture_mean(26.67) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(26.83) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(26.86) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(26.97) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(26.99) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(27.06) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(27.08) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(27.15) | 0.00351494 |
# +---------------------+------------+
# | texture_mean(27.54) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(27.61) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(27.81) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(27.85) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(27.88) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(28.03) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(28.06) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(28.08) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(28.14) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(28.2)  | 0.00175747 |
# +---------------------+------------+
# | texture_mean(28.21) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(28.23) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(28.25) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(28.77) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(28.92) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(29.29) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(29.33) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(29.37) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(29.43) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(29.81) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(29.97) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(30.62) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(30.72) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(31.12) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(32.47) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(33.56) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(33.81) | 0.00175747 |
# +---------------------+------------+
# | texture_mean(39.28) | 0.00175747 |
# +---------------------+------------+
#
# Query Result:
# +--------------+------------------+
# | diagnosis    |   phi(diagnosis) |
# +==============+==================+
# | diagnosis(0) |           0.4982 |
# +--------------+------------------+
# | diagnosis(1) |           0.5018 |
# +--------------+------------------+
